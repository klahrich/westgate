# %%
import pandas as pd
import numpy as np
from westgate.flaml_model import *
from scipy.stats import ttest_ind
from pandas.api.types import is_numeric_dtype

# %%
default_model = load_model(experiment_id='default_1.0', basefolder='../default_model/')

# %%
accepted_df = pd.read_csv('../data/AttributesLoans2022.csv', encoding='latin')
# Out:
# C:\Users\karim\AppData\Local\Temp\ipykernel_32704\3568183418.py:1: DtypeWarning: Columns (741) have mixed types. Specify dtype option on import or set low_memory=False.
#   accepted_df = pd.read_csv('../data/AttributesLoans2022.csv', encoding='latin')

# %%
accepted_df['profit'] = accepted_df['total_paid'] - accepted_df['principal']

# %%
accepted_df[default_model.target] = np.where(accepted_df['profit'] < 50, 1, 0)

# %%
filtered_df = default_model.filter_df(accepted_df)
# Out:
# Rows with 'account_age_days' column not positive will be discarded.

# %%
len(filtered_df)
# Out:
# 9507

# %%
df = filtered_df

# %% [markdown]
# # Count variables

# %%
'count_active_days' in default_model.features_in
# Out:
# False

# %%
count_vars = [c for c in df.columns if c.startswith('count_') and c not in default_model.features_in]

# %%
len(count_vars)
# Out:
# 299

# %%
stats = {'c': [], 'pvalue': [], 'stat': []}

for c in count_vars:
    refused = df.loc[df['status']==1, c]
    accepted = df.loc[df['status']==0, c]
    result = ttest_ind(refused, accepted, equal_var=False)
    stats['c'].append(c)
    stats['pvalue'].append(result.pvalue)
    stats['stat'].append(result.statistic)

# %%
count_pvalues_df = pd.DataFrame(stats)

# %%
count_pvalues_df['abs_stat'] = count_pvalues_df['stat'].abs()

# %%
count_pvalues_filtered_df = count_pvalues_df[count_pvalues_df['pvalue'] < 0.001].sort_values('abs_stat', ascending=False)

# %%
count_pvalues_filtered_df[1:20]
# Out:
#                                            c         pvalue       stat  \
# 139         count_loan_payments_7_months_ago  3.725087e-232 -33.462038
# 131        count_loan_payments_10_months_ago  9.906213e-221 -32.591626
# 137         count_loan_payments_5_months_ago  4.244575e-219 -32.444533
# 150   count_micro_loan_payments_7_months_ago  5.037600e-214 -32.073293
# 140         count_loan_payments_8_months_ago  1.572751e-211 -31.844093
# 138         count_loan_payments_6_months_ago  1.976954e-211 -31.836931
# 40     count_employer_a_income_10_months_ago  8.135873e-210 -31.724561
# 135         count_loan_payments_3_months_ago  1.306806e-207 -31.586113
# 132        count_loan_payments_11_months_ago  2.894594e-204 -31.267276
# 151   count_micro_loan_payments_8_months_ago  1.131452e-202 -31.142404
# 141         count_loan_payments_9_months_ago  2.898157e-202 -31.099870
# 41     count_employer_a_income_11_months_ago  1.170401e-200 -30.987187
# 148   count_micro_loan_payments_5_months_ago  7.798667e-194 -30.412008
# 48      count_employer_a_income_7_months_ago  2.694204e-192 -30.342532
# 49      count_employer_a_income_8_months_ago  1.903353e-190 -30.177346
# 50      count_employer_a_income_9_months_ago  2.052971e-185 -29.750868
# 142  count_micro_loan_payments_10_months_ago  1.347521e-184 -29.658480
# 149   count_micro_loan_payments_6_months_ago  3.747310e-184 -29.608639
# 146   count_micro_loan_payments_3_months_ago  2.131260e-183 -29.554880
#
#       abs_stat
# 139  33.462038
# 131  32.591626
# 137  32.444533
# 150  32.073293
# 140  31.844093
# 138  31.836931
# 40   31.724561
# 135  31.586113
# 132  31.267276
# 151  31.142404
# 141  31.099870
# 41   30.987187
# 148  30.412008
# 48   30.342532
# 49   30.177346
# 50   29.750868
# 142  29.658480
# 149  29.608639
# 146  29.554880

# %%
count_pvalues_filtered_df.to_csv('default_count_pvalues_filtered.csv', index=False)

# %%
count_top10_df = count_pvalues_filtered_df.iloc[0:10]

# %%
count_top10_df
# Out:
#                                           c         pvalue       stat  \
# 0                         count_active_days  9.895982e-255 -35.456276
# 139        count_loan_payments_7_months_ago  3.725087e-232 -33.462038
# 131       count_loan_payments_10_months_ago  9.906213e-221 -32.591626
# 137        count_loan_payments_5_months_ago  4.244575e-219 -32.444533
# 150  count_micro_loan_payments_7_months_ago  5.037600e-214 -32.073293
# 140        count_loan_payments_8_months_ago  1.572751e-211 -31.844093
# 138        count_loan_payments_6_months_ago  1.976954e-211 -31.836931
# 40    count_employer_a_income_10_months_ago  8.135873e-210 -31.724561
# 135        count_loan_payments_3_months_ago  1.306806e-207 -31.586113
# 132       count_loan_payments_11_months_ago  2.894594e-204 -31.267276
#
#       abs_stat
# 0    35.456276
# 139  33.462038
# 131  32.591626
# 137  32.444533
# 150  32.073293
# 140  31.844093
# 138  31.836931
# 40   31.724561
# 135  31.586113
# 132  31.267276

# %%
count_top10_corr = df[[c for c in count_top10_df['c']]].corr(method='spearman')

# %%
count_top10_corr_long = count_top10_corr\
                        .reset_index()\
                        .melt(id_vars = ['index']).rename(columns={'index':'var1', 'variable':'var2'})

# %%
count_top10_corr_long.query('(var1 != var2) & (value >= 0.9)')
# Out:
#                                       var1  \
# 12       count_loan_payments_10_months_ago
# 13        count_loan_payments_5_months_ago
# 14  count_micro_loan_payments_7_months_ago
# 15        count_loan_payments_8_months_ago
# 16        count_loan_payments_6_months_ago
# 21        count_loan_payments_7_months_ago
# 25        count_loan_payments_8_months_ago
# 29       count_loan_payments_11_months_ago
# 31        count_loan_payments_7_months_ago
# 35        count_loan_payments_8_months_ago
# 36        count_loan_payments_6_months_ago
# 41        count_loan_payments_7_months_ago
# 45        count_loan_payments_8_months_ago
# 46        count_loan_payments_6_months_ago
# 51        count_loan_payments_7_months_ago
# 52       count_loan_payments_10_months_ago
# 53        count_loan_payments_5_months_ago
# 54  count_micro_loan_payments_7_months_ago
# 56        count_loan_payments_6_months_ago
# 59       count_loan_payments_11_months_ago
# 61        count_loan_payments_7_months_ago
# 63        count_loan_payments_5_months_ago
# 64  count_micro_loan_payments_7_months_ago
# 65        count_loan_payments_8_months_ago
# 92       count_loan_payments_10_months_ago
# 95        count_loan_payments_8_months_ago
#
#                                       var2     value
# 12        count_loan_payments_7_months_ago  0.904298
# 13        count_loan_payments_7_months_ago  0.929250
# 14        count_loan_payments_7_months_ago  0.945357
# 15        count_loan_payments_7_months_ago  0.963249
# 16        count_loan_payments_7_months_ago  0.961853
# 21       count_loan_payments_10_months_ago  0.904298
# 25       count_loan_payments_10_months_ago  0.931165
# 29       count_loan_payments_10_months_ago  0.961818
# 31        count_loan_payments_5_months_ago  0.929250
# 35        count_loan_payments_5_months_ago  0.906581
# 36        count_loan_payments_5_months_ago  0.958944
# 41  count_micro_loan_payments_7_months_ago  0.945357
# 45  count_micro_loan_payments_7_months_ago  0.917111
# 46  count_micro_loan_payments_7_months_ago  0.913901
# 51        count_loan_payments_8_months_ago  0.963249
# 52        count_loan_payments_8_months_ago  0.931165
# 53        count_loan_payments_8_months_ago  0.906581
# 54        count_loan_payments_8_months_ago  0.917111
# 56        count_loan_payments_8_months_ago  0.935906
# 59        count_loan_payments_8_months_ago  0.907259
# 61        count_loan_payments_6_months_ago  0.961853
# 63        count_loan_payments_6_months_ago  0.958944
# 64        count_loan_payments_6_months_ago  0.913901
# 65        count_loan_payments_6_months_ago  0.935906
# 92       count_loan_payments_11_months_ago  0.961818
# 95       count_loan_payments_11_months_ago  0.907259

# %% [markdown]
# # Sum variables

# %%
sum_vars = [c for c in df.columns if c.startswith('sum_') and c not in default_model.features_in]

# %%
len(sum_vars)
# Out:
# 294

# %%
stats = {'c': [], 'pvalue': [], 'stat': []}

for c in sum_vars:
    refused = df.loc[df['status']==1, c]
    accepted = df.loc[df['status']==0, c]
    result = ttest_ind(refused, accepted, equal_var=False)
    stats['c'].append(c)
    stats['pvalue'].append(result.pvalue)
    stats['stat'].append(result.statistic)

# %%
sum_pvalues_df = pd.DataFrame(stats)

# %%
sum_pvalues_df['abs_stat'] = sum_pvalues_df['stat'].abs()

# %%
sum_pvalues_filtered_df = sum_pvalues_df[sum_pvalues_df['pvalue'] < 0.001].sort_values('abs_stat', ascending=False)

# %%
sum_top10_df = sum_pvalues_filtered_df.iloc[0:10]

# %%
sum_top10_df
# Out:
#                                        c         pvalue       stat   abs_stat
# 133                    sum_loan_payments  2.467429e-265 -35.952638  35.952638
# 66     sum_employer_income_11_months_ago  9.891878e-239 -33.962609  33.962609
# 65     sum_employer_income_10_months_ago  1.057213e-214 -32.106313  32.106313
# 141       sum_loan_payments_6_months_ago  1.118555e-207 -31.538747  31.538747
# 143       sum_loan_payments_8_months_ago  3.857794e-198 -30.763075  30.763075
# 142       sum_loan_payments_7_months_ago  5.109506e-198 -30.757252  30.757252
# 140       sum_loan_payments_5_months_ago  8.274486e-194 -30.418640  30.418640
# 73      sum_employer_income_8_months_ago  3.961306e-191 -30.178132  30.178132
# 40   sum_employer_a_income_11_months_ago  5.706387e-189 -29.998780  29.998780
# 139       sum_loan_payments_4_months_ago  1.505777e-188 -29.981858  29.981858

# %%
sum_top10_corr = df[[c for c in sum_top10_df['c']]].corr(method='spearman')

# %%
sum_top10_corr_long = sum_top10_corr\
                        .reset_index()\
                        .melt(id_vars = ['index']).rename(columns={'index':'var1', 'variable':'var2'})

# %%
sum_top10_corr_long.query('(var1 != var2) & (value >= 0.9)')
# Out:
# Empty DataFrame
# Columns: [var1, var2, value]
# Index: []

# %% [markdown]
# # Other variables

# %%
df['status'].dtype
# Out:
# dtype('int32')

# %%
other_vars = [c for c in df.columns 
                    if not c.startswith('sum_') 
                    and not c.startswith('count_')
                    and c not in default_model.features_in
                    and is_numeric_dtype(df[c])
                    ]

# %%
len(other_vars)
# Out:
# 69

# %%
stats = {'c': [], 'pvalue': [], 'stat': []}

for c in other_vars:
    refused = df.loc[df['status']==1, c]
    accepted = df.loc[df['status']==0, c]
    result = ttest_ind(refused, accepted, equal_var=False)
    stats['c'].append(c)
    stats['pvalue'].append(result.pvalue)
    stats['stat'].append(result.statistic)
# Out:
# C:\Users\karim\Documents\Westgate\.env-flaml\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
other_pvalues_df = pd.DataFrame(stats)

# %%
other_pvalues_df['abs_stat'] = other_pvalues_df['stat'].abs()

# %%
other_pvalues_filtered_df = other_pvalues_df[other_pvalues_df['pvalue'] < 0.001].sort_values('abs_stat', ascending=False)

# %%
other_pvalues_filtered_df[0:20]
# Out:
#                                                    c         pvalue  \
# 63                                            status   0.000000e+00
# 68                                            profit   0.000000e+00
# 65                                        total_paid   0.000000e+00
# 46                  recurring_deposits_11_months_ago  5.180586e-305
# 45                  recurring_deposits_10_months_ago  1.736439e-281
# 55                   recurring_deposits_9_months_ago  3.271486e-250
# 0                                   account_age_days  1.286926e-242
# 47                  recurring_deposits_12_months_ago  1.921427e-216
# 54                   recurring_deposits_8_months_ago  4.881763e-180
# 53                   recurring_deposits_7_months_ago  2.618009e-165
# 52                   recurring_deposits_6_months_ago  1.527759e-150
# 51                   recurring_deposits_5_months_ago  8.231226e-103
# 35  average_monthly_total_recurring_payments_complex  3.000640e-101
# 50                   recurring_deposits_4_months_ago  5.589481e-100
# 48                   recurring_deposits_2_months_ago   1.140082e-56
# 49                   recurring_deposits_3_months_ago   1.367971e-45
# 4                  average_employer_a_income_deposit   2.117149e-34
# 16           average_monthly_employer_income_complex   4.046638e-34
# 34  average_monthly_total_recurring_deposits_complex   1.014794e-31
# 5                  average_employer_b_income_deposit   1.444139e-28
#
#           stat    abs_stat
# 63         inf         inf
# 68 -182.745738  182.745738
# 65 -175.326505  175.326505
# 46  -38.842548   38.842548
# 45  -37.190801   37.190801
# 55  -34.893668   34.893668
# 0   -34.549700   34.549700
# 47  -32.259491   32.259491
# 54  -29.333982   29.333982
# 53  -27.996260   27.996260
# 52  -26.636729   26.636729
# 51  -21.795747   21.795747
# 35  -21.666793   21.666793
# 50  -21.491042   21.491042
# 48  -15.973240   15.973240
# 49  -14.253903   14.253903
# 4   -12.287953   12.287953
# 16  -12.233493   12.233493
# 34  -11.768926   11.768926
# 5   -11.137881   11.137881

# %% [markdown]
# # Combined

# %%
combined_df = pd.concat([count_top10_df, sum_top10_df])

# %%
combined_df.sort_values('abs_stat', ascending=False, inplace=True)

# %%
combined_df
# Out:
#                                             c         pvalue       stat  \
# 77         sum_employer_income_previous_month   0.000000e+00 -47.010470
# 68           sum_employer_income_2_months_ago   0.000000e+00 -45.207414
# 42         sum_employer_a_income_2_months_ago   0.000000e+00 -43.913843
# 51       sum_employer_a_income_previous_month   0.000000e+00 -43.284676
# 45       count_employer_a_income_2_months_ago   0.000000e+00 -42.362517
# 136          count_loan_payments_2_months_ago   0.000000e+00 -40.624764
# 145        count_loan_payments_previous_month   0.000000e+00 -39.937455
# 54     count_employer_a_income_previous_month   0.000000e+00 -39.623883
# 41               count_distinct_micro_lenders  1.604758e-305 -38.334076
# 149    count_micro_loan_payments_2_months_ago  6.095917e-292 -37.511878
# 158  count_micro_loan_payments_previous_month  7.265440e-282 -36.787331
# 137          count_loan_payments_3_months_ago  5.283274e-266 -35.722353
# 150    count_micro_loan_payments_3_months_ago  4.583513e-237 -33.622316
# 46       count_employer_a_income_3_months_ago  2.246586e-235 -33.309525
# 69           sum_employer_income_3_months_ago  1.333561e-219 -32.294065
# 149          sum_loan_payments_previous_month  1.842230e-219 -32.174720
# 140            sum_loan_payments_2_months_ago  2.381645e-201 -30.790564
# 136                         sum_loan_payments  4.595155e-189 -29.824807
# 43         sum_employer_a_income_3_months_ago  2.010103e-188 -29.808918
# 153      sum_micro_loan_payments_2_months_ago  6.719752e-174 -28.532632
#
#       abs_stat
# 77   47.010470
# 68   45.207414
# 42   43.913843
# 51   43.284676
# 45   42.362517
# 136  40.624764
# 145  39.937455
# 54   39.623883
# 41   38.334076
# 149  37.511878
# 158  36.787331
# 137  35.722353
# 150  33.622316
# 46   33.309525
# 69   32.294065
# 149  32.174720
# 140  30.790564
# 136  29.824807
# 43   29.808918
# 153  28.532632

# %%
top20_corr = df[[c for c in combined_df['c']]].corr(method='spearman')

# %%
top20_corr_long = top20_corr\
                        .reset_index()\
                        .melt(id_vars = ['index']).rename(columns={'index':'var1', 'variable':'var2'})

# %%
top20_corr_long.to_csv('refusal_top20_corr.csv', index=False)

# %%
highly_correlated_df = top20_corr_long.query('(var1 != var2) & (value >= 0.9)')
highly_correlated_df
# Out:
#                                        var1  \
# 22       count_loan_payments_previous_month
# 36           sum_loan_payments_2_months_ago
# 41         count_loan_payments_2_months_ago
# 55         sum_loan_payments_previous_month
# 119    sum_micro_loan_payments_2_months_ago
# 198      sum_employer_a_income_3_months_ago
# 302      count_loan_payments_previous_month
# 321        count_loan_payments_2_months_ago
# 369    count_employer_a_income_3_months_ago
# 385  count_micro_loan_payments_2_months_ago
#
#                                        var2     value
# 22         count_loan_payments_2_months_ago  0.900313
# 36         count_loan_payments_2_months_ago  0.926035
# 41       count_loan_payments_previous_month  0.900313
# 55       count_loan_payments_previous_month  0.918180
# 119  count_micro_loan_payments_2_months_ago  0.954152
# 198    count_employer_a_income_3_months_ago  0.933543
# 302        sum_loan_payments_previous_month  0.918180
# 321          sum_loan_payments_2_months_ago  0.926035
# 369      sum_employer_a_income_3_months_ago  0.933543
# 385    sum_micro_loan_payments_2_months_ago  0.954152

# %%
final_df = combined_df.merge(highly_correlated_df, left_on='c', right_on='var1', how='left')

# %%
final_df.to_csv('refusal_top_features.csv', index=False)
